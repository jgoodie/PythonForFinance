# %%
import numpy as np
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from pandas_datareader import data as wb
import quandl
quandl.ApiConfig.api_key = 'JgrixskwB3MtGDkJtxms'
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Interested in observing the different possible realizations of a future event
# We can use past historical data to create a simulation - a new set of fictional but sensible data
# They are a good proxy of different outcomes and are used in a number of situations
# such as: Corp Finance, Investment Valuation, Asset Mgmt, Risk Mgmt, Insurance Liabilities, 
# Pricing of Options and other derivatives
# The high level of uncertainty in Finance makes them a valuable tool.

# %%
# In Corp Fianance
# Current Revenues = Last Year Revenues * (1 + Y-O-Y Growth Rate)
# YOY Growth Rate is the unknown so we can run 1000 simulations of 
# growth rate to get an idea of average, max and min values

# %%
# Expected Revenue is $170mil with a std of $20mil
rev_m = 170
rev_stdev = 20
iterations = 1000

# %%
rev = np.random.normal(rev_m, rev_stdev, iterations)
rev
# Out:
# array([ 126.07216696,  177.19142485,  128.93700552,  163.76492152,
#         156.47844987,  229.21111555,  136.21766974,  113.92736189,
#         167.52748836,  172.05269335,  175.33111224,  164.25759747,
#         143.50855165,  168.64035485,  165.72304417,  172.17191837,
#         184.64706531,  162.06937328,  182.55466295,  175.82348219,
#         142.81158391,  197.2287921 ,  143.64241929,  170.15601076,
#         169.12289373,  189.62221315,  212.0861001 ,  143.88217265,
#         161.81264577,  158.95578683,  196.14276108,  175.26469981,
#         177.75533103,  157.80574903,  142.24295002,  195.48922995,
#         199.27154749,  185.55605683,  167.32590581,  219.11011094,
#         166.15598046,  168.4406742 ,  128.5187886 ,  206.52164781,
#         214.46361407,  203.93746183,  191.11359923,  195.61402243,
#         154.08627227,  177.21637785,  164.79965449,  149.75544359,
#         135.29966443,  156.82426094,  152.32059881,  193.17841874,
# ...

# %%
plt.figure(figsize=(15,6))
plt.plot(rev);

# %%
# COGS ~ 60% of the revenues
COGS = -(rev*np.random.normal(0.6,0.1))
plt.figure(figsize=(15,6))
plt.plot(COGS);

# %%
COGS.mean()
# Out:
# -77.81675463882118

# %%
COGS.std()
# Out:
# 9.202956711621944

# %%
Gross_Profit = rev + COGS
Gross_Profit
# Out:
# array([  68.37814363,   96.10385061,   69.93195481,   88.82167727,
#          84.86969153,  124.31792805,   73.88079076,   61.79112887,
#          90.86239206,   93.31674122,   95.09486721,   89.08889142,
#          77.83516849,   91.46598083,   89.88371019,   93.38140565,
#         100.14758894,   87.90205763,   99.01272633,   95.3619154 ,
#          77.45715198,  106.97157827,   77.90777469,   92.28803173,
#          91.72769691,  102.84597497,  115.02978148,   78.03781045,
#          87.76281554,   86.2133323 ,  106.38254433,   95.0588469 ,
#          96.40969811,   85.58958281,   77.1487403 ,  106.02808667,
#         108.0795137 ,  100.64060143,   90.75305912,  118.83941554,
#          90.11852316,   91.35767943,   69.70512523,  112.01177261,
#         116.31928094,  110.61017982,  103.65486256,  106.09577074,
#          83.57223891,   96.11738444,   89.38288853,   81.22331422,
#          73.38288943,   85.05725014,   82.61458524,  104.77476498,
# ...

# %%
plt.figure(figsize=(15,6))
plt.plot(Gross_Profit);

# %%
np.max(Gross_Profit)
# Out:
# 128.85460414971001

# %%
np.min(Gross_Profit)
# Out:
# 56.484019291630943

# %%
np.mean(Gross_Profit)
# Out:
# 92.227321294526007

# %%
np.std(Gross_Profit)
# Out:
# 10.907214640880701

# %%
plt.figure(figsize=(10,6))
plt.hist(Gross_Profit, bins=[40,50,60,70,80,90,100,110,120]);

# %%
plt.figure(figsize=(10,6))
plt.hist(Gross_Profit, bins=40);
