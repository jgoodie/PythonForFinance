# %%
import time
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import quandl
quandl.ApiConfig.api_key = 'JgrixskwB3MtGDkJtxms'
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# S&P500 = ^GSPC
# NASDAQ = ^IXIC
# DAX = ^GDAXI (Germany)
# Financial Times Stock Ex = ^FTSE (London/UK)

# %%
indices = ['^GSPC', '^IXIC', '^GDAXI', '^FTSE']

# %%
ind_data = pd.DataFrame()

# %%
for i in indices:
    ind_data[i] = wb.DataReader(i, data_source='yahoo', start='1997-01-01')['Adj Close']
    time.sleep(20)

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI        ^FTSE
# Date
# 1997-01-02  737.010010  1280.699951  2820.810059  4057.399902
# 1997-01-03  748.030029  1310.680054  2863.260010  4089.500000
# 1997-01-06  747.650024  1316.400024  2890.199951  4106.500000
# 1997-01-07  753.229980  1327.729980  2876.340088  4078.800049
# 1997-01-08  748.409973  1320.349976  2904.080078  4087.500000

# %%
# Normalize the data
ind_data_norm = (ind_data/ind_data.iloc[0])*100

# %%
ind_data_norm.head()
# Out:
#                  ^GSPC       ^IXIC      ^GDAXI       ^FTSE
# Date
# 1997-01-02  100.000000  100.000000  100.000000  100.000000
# 1997-01-03  101.495233  102.340915  101.504885  100.791149
# 1997-01-06  101.443673  102.787544  102.459928  101.210137
# 1997-01-07  102.200780  103.672213  101.968584  100.527435
# 1997-01-08  101.546785  103.095965  102.951990  100.741857

# %%
ind_data_norm.plot(figsize=(12,8));

# %%
ind_rets = (ind_data/ind_data.shift(1))-1

# %%
ind_rets.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI     ^FTSE
# Date
# 2017-10-09 -0.001804 -0.001586  0.001579 -0.001994
# 2017-10-10  0.002322  0.001143 -0.002092  0.004049
# 2017-10-11  0.001804  0.002474  0.001655 -0.000597
# 2017-10-12 -0.001687 -0.001823  0.000941  0.002973
# 2017-10-13  0.000878  0.002168  0.000692 -0.002753

# %%
ind_annual_rets = ind_rets.mean()*250

# %%
ind_annual_rets
# Out:
# ^GSPC     0.077863
# ^IXIC     0.110354
# ^GDAXI    0.087207
# ^FTSE     0.044189
# dtype: float64

# %%
tickers = ['PG', '^GSPC', '^DJI']
data_2 = pd.DataFrame()

# %%
for t in tickers:
    data_2[t] = wb.DataReader(t, data_source='yahoo', start='1997-01-01')['Adj Close']
    time.sleep(20)

# %%
data_2.tail()
# Out:
#                    PG        ^GSPC          ^DJI
# Date
# 2017-10-09  92.120003  2544.729980  22761.070313
# 2017-10-10  91.620003  2550.639893  22830.679688
# 2017-10-11  91.459999  2555.239990  22872.890625
# 2017-10-12  92.150002  2550.929932  22841.009766
# 2017-10-13  93.040001  2553.169922  22871.720703

# %%
data_2_norm = (data_2/data_2.iloc[0])*100

# %%
data_2_norm.head()
# Out:
#                     PG       ^GSPC        ^DJI
# Date
# 1997-01-02  100.000000  100.000000  100.000000
# 1997-01-03  101.641307  101.495233  101.577024
# 1997-01-06  102.344675  101.443673  101.935431
# 1997-01-07  104.220430  102.200780  102.455105
# 1997-01-08  102.344675  101.546785  101.660689

# %%
data_2_norm.plot(figsize=(12,8));
