# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col=0)
df2 = pd.read_csv('df2')

# %%
df1['A'].hist(bins=30)

# %%
df1['A'].plot(kind='hist', bins=30)

# %%
df1['A'].plot.hist()

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area(alpha=0.4)

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df1['A'].plot.hist(bins=50)

# %%
df1.plot.line(x=df1.index, y='B', figsize=(12,3), lw=1)

# %%
df1.plot.scatter(x='A', y='B', c='C')

# %%
# https://matplotlib.org/examples/color/colormaps_reference.html
df1.plot.scatter(x='A', y='B', c='C', cmap='Accent')

# %%
df1.plot.scatter(x='A', y='B', c='C',cmap="magma", s=df1['C']*100)
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/collections.py:877: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(10000,2),columns=['a','b'])
df.head()
# Out:
#           a         b
# 0  1.708452  0.620429
# 1  1.315610  0.757523
# 2  0.838055 -0.519271
# 3  0.202797 -0.097097
# 4  0.339759 -0.154643

# %%
df.plot.hexbin(x='a',y='b', gridsize=25, cmap='plasma')

# %%
df2.plot.kde()

# %%
df2['a'].plot.kde()

# %%
df2.plot.density()

# %%
sns.set(style="ticks")

# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")

# Show the results of a linear regression within each dataset
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="muted", size=4,
           scatter_kws={"s": 50, "alpha": 1})

# %%
df = sns.load_dataset("iris")
sns.pairplot(df, hue="species")
