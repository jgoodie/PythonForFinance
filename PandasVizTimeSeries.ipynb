# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as dates
# %matplotlib inline
# make plts interactive && restart kernel
#%matplotlib notebook

# %%
df = pd.read_csv("mcdonalds.csv", index_col='Date', parse_dates=True)
df.head()
# Out:
#             Adj. Close  Adj. Volume
# Date
# 1970-01-02    0.209761    2825604.0
# 1970-01-05    0.213316    2210449.5
# 1970-01-06    0.214501    1951168.5
# 1970-01-07    0.213316    2728768.5
# 1970-01-08    0.213316    2242404.0

# %%
df['Adj. Close'].plot()

# %%
df['Adj. Volume'].plot(figsize=(16,4))

# %%
df['Adj. Close'].plot(xlim=['2007-01-01','2009-01-01'])

# %%
df['Adj. Close'].plot(xlim=['2007-01-01','2009-01-01'], ylim=[20,60])

# %%
df['Adj. Close'].plot(xlim=['2007-01-01','2009-01-01'], ylim=[20,60], ls='--', c='purple')

# %%
#import matplotlib.dates as dates

# %%
df['Adj. Close'].plot(xlim=['2007-01-01','2009-01-01'], ylim=[20,60], ls='-', c='purple')

# %%
idx = df.loc['2007-01-01':'2007-05-01'].index
stock = df.loc['2007-01-01':'2007-05-01']['Adj. Close']

# %%
fig,ax = plt.subplots()
ax.plot_date(idx,stock,'-')
ax.yaxis.grid(True)
ax.xaxis.grid(True)
fig.autofmt_xdate()
plt.tight_layout()

# %%
fig,ax = plt.subplots()
ax.plot_date(idx,stock,'-')
#LOCATING
# pass in dates from matplotlib.dates import
ax.xaxis.set_major_locator(dates.MonthLocator())
ax.xaxis.set_minor_locator(dates.WeekdayLocator(byweekday=0))
#FORMATTING
ax.xaxis.set_major_formatter(dates.DateFormatter('\n\n %b-%Y')) # can add in newline
ax.xaxis.set_minor_formatter(dates.DateFormatter('%d'))

fig.autofmt_xdate()
plt.tight_layout()
